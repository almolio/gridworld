# %%
# imports
from os import walk
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils.dataloader import GridDataLoader
from envs.environment_ben import Environment

# %% [markdown]
# Example of use case environment.py

# %%
data_dir='../data'
variant = 0
env = Environment(variant, data_dir)
env.reward
# Out:
# 15

# %% [markdown]
# Example of use case dataloader.py

# %%
# data extraction parameters
test_val_train = 'train'
variant = 0
dl=GridDataLoader(variant,test_val_train)

# %%
dl.filenames[0]
episode=dl.load_rdn_episode()
episode[:10]
# Out:
# [[13, 2, 0],
#  [13, 4, 3],
#  [18, 3, 3],
#  [30, 1, 1],
#  [32, 0, 3],
#  [32, 1, 3],
#  [36, 3, 4],
#  [48, 2, 2],
#  [53, 3, 2],
#  [58, 3, 2]]

# %%
dl.display_distribution()
